# %%
from pymouse import PyMouse
import pygame
import time
from IPython.display import clear_output

# %%
m = PyMouse()

# %%
dir(m)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__doc__',
#  '__format__',
#  '__getattribute__',
#  '__hash__',
#  '__init__',
#  '__module__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'click',
#  'move',
#  'position',
#  'press',
#  'release',
#  'screen_size']

# %%
x = m.position()
m.move(x[0]-100, x[1]-100)

# %%
m.press?

# %%
m.release?

# %%
pygame.init()

pygame.joystick.init()
clock = pygame.time.Clock()

joystick_count = pygame.joystick.get_count()
while True:
    for i in range(joystick_count):
            joystick = pygame.joystick.Joystick(i)
            joystick.init()

            print("Joystick {}".format(i))

            # Get the name from the OS for the controller/joystick
            name = joystick.get_name()
            print "Joystick name: {}".format(name)

            # Usually axis run in pairs, up/down for one, and left/right for
            # the other.
            axes = joystick.get_numaxes()
            print "Number of axes: {}".format(axes)

            for i in range( axes ):
                axis = joystick.get_axis( i )
                print "Axis {} value: {:>6.3f}".format(i, axis)

            buttons = joystick.get_numbuttons()
            print "Number of buttons: {}".format(buttons)
    clock.tick(20)
# Out:
# Joystick 0
# Joystick name: XBOX 360 For Windows (Controller)
# Number of axes: 5
# Axis 0 value:  0.091
# Axis 1 value:  0.050
# Axis 2 value:  0.000
# Axis 3 value: -0.074
# Axis 4 value: -0.008
# Number of buttons: 10
# Joystick 0
# Joystick name: XBOX 360 For Windows (Controller)
# Number of axes: 5
# Axis 0 value:  0.091
# Axis 1 value:  0.050
# Axis 2 value:  0.000
# Axis 3 value: -0.074
# Axis 4 value: -0.008
# Number of buttons: 10
# Joystick 0
# Joystick name: XBOX 360 For Windows (Controller)
# Number of axes: 5
# Axis 0 value:  0.091
# Axis 1 value:  0.050
# Axis 2 value:  0.000
# Axis 3 value: -0.074
# Axis 4 value: -0.008
# Number of buttons: 10
# Joystick 0
# Joystick name: XBOX 360 For Windows (Controller)
# Number of axes: 5
# Axis 0 value:  0.091
# Axis 1 value:  0.050
# Axis 2 value:  0.000
# Axis 3 value: -0.074
# Axis 4 value: -0.008
# Number of buttons: 10
# Joystick 0
# Joystick name: XBOX 360 For Windows (Controller)
# Number of axes: 5
# Axis 0 value:  0.091
# Axis 1 value:  0.050
# Axis 2 value:  0.000
# Axis 3 value: -0.074
# Axis 4 value: -0.008
# Number of buttons: 10
# Joystick 0
# Joystick name: XBOX 360 For Windows (Controller)
# Number of axes: 5
# Axis 0 value:  0.091
# Axis 1 value:  0.050
# Axis 2 value:  0.000
# Axis 3 value: -0.074
# Axis 4 value: -0.008
# Number of buttons: 10
# Joystick 0
# Joystick name: XBOX 360 For Windows (Controller)
# Number of axes: 5
# Axis 0 value:  0.091
# Axis 1 value:  0.050
# Axis 2 value:  0.000
# Axis 3 value: -0.074
# Axis 4 value: -0.008
# Number of buttons: 10
# Joystick 0
# Joystick name: XBOX 360 For Windows (Controller)
# Number of axes: 5
# Axis 0 value:  0.091
# Axis 1 value:  0.050
# Axis 2 value:  0.000
# Axis 3 value: -0.074
# Axis 4 value: -0.008
# Number of buttons: 10
# Joystick 0
# Joystick name: XBOX 360 For Windows (Controller)
# Number of axes: 5
# Axis 0 value:  0.091
# Axis 1 value:  0.050
# Axis 2 value:  0.000
# Axis 3 value: -0.074
# Axis 4 value: -0.008
# Number of buttons: 10
# Joystick 0
# Joystick name: XBOX 360 For Windows (Controller)
# Number of axes: 5
# Axis 0 value:  0.091
# Axis 1 value:  0.050
# Axis 2 value:  0.000
# Axis 3 value: -0.074
# Axis 4 value: -0.008
# Number of buttons: 10
# Joystick 0
# Joystick name: XBOX 360 For Windows (Controller)
# Number of axes: 5
# Axis 0 value:  0.091
# Axis 1 value:  0.050
# Axis 2 value:  0.000
# Axis 3 value: -0.074
# Axis 4 value: -0.008
# Number of buttons: 10
# Joystick 0
# Joystick name: XBOX 360 For Windows (Controller)
# Number of axes: 5
# Axis 0 value:  0.091
# Axis 1 value:  0.050
# Axis 2 value:  0.000
# Axis 3 value: -0.074
# Axis 4 value: -0.008
# Number of buttons: 10
# Joystick 0
# Joystick name: XBOX 360 For Windows (Controller)
# Number of axes: 5
# Axis 0 value:  0.091
# Axis 1 value:  0.050
# Axis 2 value:  0.000
# Axis 3 value: -0.074
# Axis 4 value: -0.008
# Number of buttons: 10
# Joystick 0
# Joystick name: XBOX 360 For Windows (Controller)
# Number of axes: 5
# Axis 0 value:  0.091
# Axis 1 value:  0.050
# Axis 2 value:  0.000
# Axis 3 value: -0.074
# Axis 4 value: -0.008
# Number of buttons: 10
# Joystick 0
# Joystick name: XBOX 360 For Windows (Controller)
# Number of axes: 5
# Axis 0 value:  0.091
# Axis 1 value:  0.050
# Axis 2 value:  0.000
# Axis 3 value: -0.074
# Axis 4 value: -0.008
# Number of buttons: 10
# Joystick 0
# Joystick name: XBOX 360 For Windows (Controller)
# Number of axes: 5
# Axis 0 value:  0.091
# Axis 1 value:  0.050
# Axis 2 value:  0.000
# Axis 3 value: -0.074
# Axis 4 value: -0.008
# Number of buttons: 10
# Joystick 0
# Joystick name: XBOX 360 For Windows (Controller)
# Number of axes: 5
# Axis 0 value:  0.091
# Axis 1 value:  0.050
# Axis 2 value:  0.000
# Axis 3 value: -0.074
# Axis 4 value: -0.008
# Number of buttons: 10
# Joystick 0
# Joystick name: XBOX 360 For Windows (Controller)
# Number of axes: 5
# Axis 0 value:  0.091
# Axis 1 value:  0.050
# Axis 2 value:  0.000
# Axis 3 value: -0.074
# Axis 4 value: -0.008
# Number of buttons: 10
# Joystick 0
# Joystick name: XBOX 360 For Windows (Controller)
# Number of axes: 5
# Axis 0 value:  0.091
# Axis 1 value:  0.050
# Axis 2 value:  0.000
# Axis 3 value: -0.074
# Axis 4 value: -0.008
# Number of buttons: 10
# Joystick 0
# Joystick name: XBOX 360 For Windows (Controller)
# Number of axes: 5
# Axis 0 value:  0.091
# Axis 1 value:  0.050
# Axis 2 value:  0.000
# Axis 3 value: -0.074
# Axis 4 value: -0.008
# Number of buttons: 10
# Joystick 0
# Joystick name: XBOX 360 For Windows (Controller)
# Number of axes: 5
# Axis 0 value:  0.091
# Axis 1 value:  0.050
# Axis 2 value:  0.000
# Axis 3 value: -0.074
# Axis 4 value: -0.008
# Number of buttons: 10
# Joystick 0
# Joystick name: XBOX 360 For Windows (Controller)
# Number of axes: 5
# Axis 0 value:  0.091
# Axis 1 value:  0.050
# Axis 2 value:  0.000
# Axis 3 value: -0.074
# Axis 4 value: -0.008
# Number of buttons: 10
# Joystick 0
# Joystick name: XBOX 360 For Windows (Controller)
# Number of axes: 5
# Axis 0 value:  0.091
# Axis 1 value:  0.050
# Axis 2 value:  0.000
# Axis 3 value: -0.074
# Axis 4 value: -0.008
# Number of buttons: 10
# Joystick 0
# Joystick name: XBOX 360 For Windows (Controller)
# Number of axes: 5
# Axis 0 value:  0.091
# Axis 1 value:  0.050
# Axis 2 value:  0.000
# Axis 3 value: -0.074
# Axis 4 value: -0.008
# Number of buttons: 10
# Joystick 0
# Joystick name: XBOX 360 For Windows (Controller)
# Number of axes: 5
# Axis 0 value:  0.091
# Axis 1 value:  0.050
# Axis 2 value:  0.000
# Axis 3 value: -0.074
# Axis 4 value: -0.008
# Number of buttons: 10
# Joystick 0
# Joystick name: XBOX 360 For Windows (Controller)
# Number of axes: 5
# Axis 0 value:  0.091
# Axis 1 value:  0.050
# Axis 2 value:  0.000
# Axis 3 value: -0.074
# Axis 4 value: -0.008
# Number of buttons: 10
# Joystick 0
# Joystick name: XBOX 360 For Windows (Controller)
# Number of axes: 5
# Axis 0 value:  0.091
# Axis 1 value:  0.050
# Axis 2 value:  0.000
# Axis 3 value: -0.074
# Axis 4 value: -0.008
# Number of buttons: 10
# Joystick 0
# Joystick name: XBOX 360 For Windows (Controller)
# Number of axes: 5
# Axis 0 value:  0.091
# Axis 1 value:  0.050
# Axis 2 value:  0.000
# Axis 3 value: -0.074
# Axis 4 value: -0.008
# Number of buttons: 10
# Joystick 0
# Joystick name: XBOX 360 For Windows (Controller)
# Number of axes: 5
# Axis 0 value:  0.091
# Axis 1 value:  0.050
# Axis 2 value:  0.000
# Axis 3 value: -0.074
# Axis 4 value: -0.008
# Number of buttons: 10
# Joystick 0
# Joystick name: XBOX 360 For Windows (Controller)
# Number of axes: 5
# Axis 0 value:  0.091
# Axis 1 value:  0.050
# Axis 2 value:  0.000
# Axis 3 value: -0.074
# Axis 4 value: -0.008
# Number of buttons: 10
# Joystick 0
# Joystick name: XBOX 360 For Windows (Controller)
# Number of axes: 5
# Axis 0 value:  0.091
# Axis 1 value:  0.050
# Axis 2 value:  0.000
# Axis 3 value: -0.074
# Axis 4 value: -0.008
# Number of buttons: 10
# Joystick 0
# Joystick name: XBOX 360 For Windows (Controller)
# Number of axes: 5
# Axis 0 value:  0.091
# Axis 1 value:  0.050
# Axis 2 value:  0.000
# Axis 3 value: -0.074
# Axis 4 value: -0.008
# Number of buttons: 10
# Joystick 0
# Joystick name: XBOX 360 For Windows (Controller)
# Number of axes: 5
# Axis 0 value:  0.091
# Axis 1 value:  0.050
# Axis 2 value:  0.000
# Axis 3 value: -0.074
# Axis 4 value: -0.008
# Number of buttons: 10
# Joystick 0
# Joystick name: XBOX 360 For Windows (Controller)
# Number of axes: 5
# Axis 0 value:  0.091
# Axis 1 value:  0.050
# Axis 2 value:  0.000
# Axis 3 value: -0.074
# Axis 4 value: -0.008
# Number of buttons: 10
# Joystick 0
# Joystick name: XBOX 360 For Windows (Controller)
# Number of axes: 5
# Axis 0 value:  0.091
# Axis 1 value:  0.050
# Axis 2 value:  0.000
# Axis 3 value: -0.074
# Axis 4 value: -0.008
# Number of buttons: 10
# Joystick 0
# Joystick name: XBOX 360 For Windows (Controller)
# Number of axes: 5
# Axis 0 value:  0.091
# Axis 1 value:  0.050
# Axis 2 value:  0.000
# Axis 3 value: -0.074
# Axis 4 value: -0.008
# Number of buttons: 10
# Joystick 0
# Joystick name: XBOX 360 For Windows (Controller)
# Number of axes: 5
# Axis 0 value:  0.091
# Axis 1 value:  0.050
# Axis 2 value:  0.000
# Axis 3 value: -0.074
# Axis 4 value: -0.008
# Number of buttons: 10
# Joystick 0
# Joystick name: XBOX 360 For Windows (Controller)
# Number of axes: 5
# Axis 0 value:  0.091
# Axis 1 value:  0.050
# Axis 2 value:  0.000
# Axis 3 value: -0.074
# Axis 4 value: -0.008
# Number of buttons: 10
# Joystick 0
# Joystick name: XBOX 360 For Windows (Controller)
# Number of axes: 5
# Axis 0 value:  0.091
# Axis 1 value:  0.050
# Axis 2 value:  0.000
# Axis 3 value: -0.074
# Axis 4 value: -0.008
# Number of buttons: 10
# Joystick 0
# Joystick name: XBOX 360 For Windows (Controller)
# Number of axes: 5
# Axis 0 value:  0.091
# Axis 1 value:  0.050
# Axis 2 value:  0.000
# Axis 3 value: -0.074
# Axis 4 value: -0.008
# Number of buttons: 10
# Joystick 0
# Joystick name: XBOX 360 For Windows (Controller)
# Number of axes: 5
# Axis 0 value:  0.091
# Axis 1 value:  0.050
# Axis 2 value:  0.000
# Axis 3 value: -0.074
# Axis 4 value: -0.008
# Number of buttons: 10
# Joystick 0
# Joystick name: XBOX 360 For Windows (Controller)
# Number of axes: 5
# Axis 0 value:  0.091
# Axis 1 value:  0.050
# Axis 2 value:  0.000
# Axis 3 value: -0.074
# Axis 4 value: -0.008
# Number of buttons: 10
# Joystick 0
# Joystick name: XBOX 360 For Windows (Controller)
# Number of axes: 5
# Axis 0 value:  0.091
# Axis 1 value:  0.050
# Axis 2 value:  0.000
# Axis 3 value: -0.074
# Axis 4 value: -0.008
# Number of buttons: 10
# Joystick 0
# Joystick name: XBOX 360 For Windows (Controller)
# Number of axes: 5
# Axis 0 value:  0.091
# Axis 1 value:  0.050
# Axis 2 value:  0.000
# Axis 3 value: -0.074
# Axis 4 value: -0.008
# Number of buttons: 10
# Joystick 0
# Joystick name: XBOX 360 For Windows (Controller)
# Number of axes: 5
# Axis 0 value:  0.091
# Axis 1 value:  0.050
# Axis 2 value:  0.000
# Axis 3 value: -0.074
# Axis 4 value: -0.008
# Number of buttons: 10
# Joystick 0
# Joystick name: XBOX 360 For Windows (Controller)
# Number of axes: 5
# Axis 0 value:  0.091
# Axis 1 value:  0.050
# Axis 2 value:  0.000
# Axis 3 value: -0.074
# Axis 4 value: -0.008
# Number of buttons: 10
# Joystick 0
# Joystick name: XBOX 360 For Windows (Controller)
# Number of axes: 5
# Axis 0 value:  0.091
# Axis 1 value:  0.050
# Axis 2 value:  0.000
# Axis 3 value: -0.074
# Axis 4 value: -0.008
# Number of buttons: 10
# Joystick 0
# Joystick name: XBOX 360 For Windows (Controller)
# Number of axes: 5
# Axis 0 value:  0.091
# Axis 1 value:  0.050
# Axis 2 value:  0.000
# Axis 3 value: -0.074
# Axis 4 value: -0.008
# Number of buttons: 10
# Joystick 0
# Joystick name: XBOX 360 For Windows (Controller)
# Number of axes: 5
# Axis 0 value:  0.091
# Axis 1 value:  0.050
# Axis 2 value:  0.000
# Axis 3 value: -0.074
# Axis 4 value: -0.008
# Number of buttons: 10
# Joystick 0
# Joystick name: XBOX 360 For Windows (Controller)
# Number of axes: 5
# Axis 0 value:  0.091
# Axis 1 value:  0.050
# Axis 2 value:  0.000
# Axis 3 value: -0.074
# Axis 4 value: -0.008
# Number of buttons: 10
# Joystick 0
# Joystick name: XBOX 360 For Windows (Controller)
# Number of axes: 5
# Axis 0 value:  0.091
# Axis 1 value:  0.050
# Axis 2 value:  0.000
# Axis 3 value: -0.074
# Axis 4 value: -0.008
# Number of buttons: 10
# Joystick 0
# Joystick name: XBOX 360 For Windows (Controller)
# Number of axes: 5
# Axis 0 value:  0.091
# Axis 1 value:  0.050
# Axis 2 value:  0.000
# Axis 3 value: -0.074
# Axis 4 value: -0.008
# Number of buttons: 10
# Joystick 0
# Joystick name: XBOX 360 For Windows (Controller)
# Number of axes: 5
# Axis 0 value:  0.091
# Axis 1 value:  0.050
# Axis 2 value:  0.000
# Axis 3 value: -0.074
# Axis 4 value: -0.008
# Number of buttons: 10
# Joystick 0
# Joystick name: XBOX 360 For Windows (Controller)
# Number of axes: 5
# Axis 0 value:  0.091
# Axis 1 value:  0.050
# Axis 2 value:  0.000
# Axis 3 value: -0.074
# Axis 4 value: -0.008
# Number of buttons: 10
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-28246255ffc8> in <module>()
#      27             buttons = joystick.get_numbuttons()
#      28             print "Number of buttons: {}".format(buttons)
# ---> 29     clock.tick(20)
#
# KeyboardInterrupt:

# %%
while True:
    for event in pygame.event.get(): # User did something
        if event.type == pygame.QUIT: # If user clicked close
            done=True # Flag that we are done so we exit this loop
        
        # Possible joystick actions: JOYAXISMOTION JOYBALLMOTION JOYBUTTONDOWN JOYBUTTONUP JOYHATMOTION
        if event.type == pygame.JOYBUTTONDOWN:
            print("Joystick button pressed.")
        if event.type == pygame.JOYBUTTONUP:
            print("Joystick button released.")
# Out:
# Joystick button pressed.
# Joystick button released.
# Joystick button pressed.
# Joystick button released.
# Joystick button pressed.
# Joystick button released.
# Joystick button pressed.
# Joystick button released.
# Joystick button pressed.
# Joystick button released.
# Joystick button pressed.
# Joystick button released.
# Joystick button pressed.
# Joystick button pressed.
# Joystick button released.
# Joystick button released.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-22-538ad4c05e96> in <module>()
#       8             print("Joystick button pressed.")
#       9         if event.type == pygame.JOYBUTTONUP:
# ---> 10             print("Joystick button released.")
#
# KeyboardInterrupt:
